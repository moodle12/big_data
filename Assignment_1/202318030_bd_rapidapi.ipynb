# %% [markdown]
# **Name : Mahmood Topiwala**
#
# **Student ID : 202318030**

# %% [markdown]
# **Dataset 1**

# %%
import pandas as pd
import requests

# %%
import requests

url = "https://mashape-community-urban-dictionary.p.rapidapi.com/define"

querystring = {"term":"wat"}

headers = {
	"X-RapidAPI-Key": "9aafbf952dmsh02ecc3e2f610aa2p17d800jsn8e93ce59f794",
	"X-RapidAPI-Host": "mashape-community-urban-dictionary.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'list': [{'definition': 'The only [proper] [response] to something that makes absolutely [no sense].', 'permalink': 'http://wat.urbanup.com/3322419', 'thumbs_up': 3985, 'author': 'watwat', 'word': 'wat', 'defid': 3322419, 'current_vote': '', 'written_on': '2008-09-04T09:15:08.000Z', 'example': "1: If all the animals on the [equator] were capable of [flattery], Halloween and Easter would fall on the same day.\r\n2: wat\r\n\r\n1: Wow your cock is almost as big as my dad's.\r\n2: wat\r\n\r\n1: I accidentially a whole [coke bottle]\r\n2: You accidentially what?\r\n1: A whole coke bottle\r\n2: wat", 'thumbs_down': 443}, {'definition': 'Slang.  Indicates [confusion] or [a need] for [clarification].  Statement/question.', 'permalink': 'http://wat.urbanup.com/1308686', 'thumbs_up': 1218, 'author': 'stewpidwhytemayun', 'word': 'wat', 'defid': 1308686, 'current_vote': '', 'written_on': '2005-06-08T23:20:56.000Z', 'example': '1: "[lolz] Yea sex is great and everything but its way too overrated
# ...

# %%
import pandas as pd

definitions_list = response.json()
x = definitions_list.get("list")
x
# Created a DataFrame from the list of definitions
res = pd.DataFrame(x)[['definition', 'permalink', 'thumbs_up', 'author', 'word', 'defid', 'written_on', 'thumbs_down']]

#  the DataFrame
res
# Out:
#                                           definition  \
# 0  The only [proper] [response] to something that...
# 1  Slang.  Indicates [confusion] or [a need] for ...
# 2  ‎[Wat] is the internet troll equivalent to wha...
# 3  A word, that when perfectly placed, is a power...
# 4  Short form of "what". Is usually used by peopl...
# 5  What one says when they're [devoid] of any par...
# 6  [Thai] [temple], found all over [Thailand]. Pr...
# 7  [the meme] version of what you just [take out]...
# 8  Wat is short for "What" but is only spelt "Wat...
# 9  An [utterance] one would say if [someone else]...
#
#                          permalink  thumbs_up              author word  \
# 0   http://wat.urbanup.com/3322419       3985              watwat  wat
# 1   http://wat.urbanup.com/1308686       1218   stewpidwhytemayun  wat
# 2   http://wat.urbanup.com/5112312        214          Razgriz117  wat
# 3   http://wat.urbanup.com/3351192        360            Nevandal  wat
# ...

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   definition   10 non-null     object
#  1   permalink    10 non-null     object
#  2   thumbs_up    10 non-null     int64
#  3   author       10 non-null     object
#  4   word         10 non-null     object
#  5   defid        10 non-null     int64
#  6   written_on   10 non-null     object
#  7   thumbs_down  10 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 768.0+ bytes

# %%
res.shape
# Out:
# (10, 8)

# %% [markdown]
# **Dataset 2**

# %%
url = "https://odds.p.rapidapi.com/v4/sports/upcoming/odds"

querystring = {"regions":"us","oddsFormat":"decimal","markets":"h2h,spreads","dateFormat":"iso"}

headers = {
	"X-RapidAPI-Key": "41caf346c9mshc3697f9cf1829f2p1dbd16jsnd9a945715bb4",
	"X-RapidAPI-Host": "odds.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'id': '44a079ed98217dbe89215260e04920fa', 'sport_key': 'soccer_turkey_super_league', 'sport_title': 'Turkey Super League', 'commence_time': '2023-12-25T14:00:00Z', 'home_team': 'Alanyaspor', 'away_team': 'Samsunspor', 'bookmakers': [{'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-12-25T07:25:04Z', 'markets': [{'key': 'h2h', 'last_update': '2023-12-25T07:25:04Z', 'outcomes': [{'name': 'Alanyaspor', 'price': 2.3}, {'name': 'Samsunspor', 'price': 2.9}, {'name': 'Draw', 'price': 3.3}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-12-25T07:25:00Z', 'markets': [{'key': 'h2h', 'last_update': '2023-12-25T07:25:00Z', 'outcomes': [{'name': 'Alanyaspor', 'price': 2.35}, {'name': 'Samsunspor', 'price': 3.0}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-12-25T07:26:17Z', 'markets': [{'key': 'h2h', 'last_update': '2023-12-25T07:26:17Z', 'outcomes': [{'name': 'Alanyaspor', 'price': 2.35}, {'name': 'S
# ...

# %%
response=pd.DataFrame(response.json())[['id',	'sport_key','sport_title',	'commence_time',	'home_team',	'away_team']]

# %%
response.shape
# Out:
# (8, 6)

# %%
response
# Out:
#                                  id                   sport_key  \
# 0  44a079ed98217dbe89215260e04920fa  soccer_turkey_super_league
# 1  d7d545b2bcc81d1bd2f2107bc6605996  soccer_turkey_super_league
# 2  89673ef5880a6aabdb205dc805b4c022  soccer_turkey_super_league
# 3  6a504e54b3245994b3cd51ad92ae4aa6  soccer_turkey_super_league
# 4  5a4b28938902c4fba16da19c6e8c1296              basketball_nba
# 5  25aea15aa16519945e654a0a5158ccf0        americanfootball_nfl
# 6  20fc47de6083f99da2027876dfebadb7              basketball_nba
# 7  361a376a7fe6aa6a72a42331299683dc        americanfootball_nfl
#
#            sport_title         commence_time            home_team  \
# 0  Turkey Super League  2023-12-25T14:00:00Z           Alanyaspor
# 1  Turkey Super League  2023-12-25T14:00:00Z         Kasimpasa SK
# 2  Turkey Super League  2023-12-25T17:00:00Z           Pendikspor
# 3  Turkey Super League  2023-12-25T17:00:00Z            Hatayspor
# ...

# %%
response.to_csv('sports.csv')
